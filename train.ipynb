# %%
import logging
import os
import json
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import nibabel as nib

# %%
# --- Logging ---
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# --- Dataset ---
class HeartDataset(Dataset):
    def __init__(self, data_dir, cases, transform=None, patch_size=(96, 96, 96)):
        self.data_dir = data_dir
        self.cases = cases
        self.transform = transform
        self.patch_size = patch_size

    def __len__(self):
        return len(self.cases)

    def __getitem__(self, idx):
        case = self.cases[idx]
        try:
            img_path = os.path.join(self.data_dir, 'imagesTr', f"{case}.nii.gz")
            label_path = os.path.join(self.data_dir, 'labelsTr', f"{case}.nii.gz")
            
            img = nib.load(img_path).get_fdata().astype(np.float32)
            label = nib.load(label_path).get_fdata().astype(np.int64)
            
            img = np.clip(img, -1000, 1000)
            img = (img + 1000) / 2000.0
            img = np.expand_dims(img, axis=0)
            
            img = torch.from_numpy(img.copy())
            label = torch.from_numpy(label.copy())

            if self.patch_size:
                img, label = self.atrium_aware_crop(img, label, self.patch_size)
            
            return img, label

        except Exception as e:
            logger.error(f"Error loading case {case}: {e}")
            dummy_img = torch.zeros((1,) + self.patch_size)
            dummy_label = torch.zeros(self.patch_size, dtype=torch.long)
            return dummy_img, dummy_label

    def atrium_aware_crop(self, img, label, patch_size):
        d, h, w = img.shape[1:]
        pd, ph, pw = patch_size

        # Try to find a crop containing left atrium (label == 1)
        for _ in range(10):  # Increased attempts for better atrium sampling
            start_d = np.random.randint(0, max(1, d - pd + 1))
            start_h = np.random.randint(0, max(1, h - ph + 1))
            start_w = np.random.randint(0, max(1, w - pw + 1))

            label_crop = label[start_d:start_d+pd, start_h:start_h+ph, start_w:start_w+pw]
            atrium_ratio = (label_crop == 1).float().mean().item()
            
            # Accept if we have some atrium voxels (lowered threshold for heart segmentation)
            if atrium_ratio > 0.0005:
                break
        else:
            # If no atrium found after 10 attempts, use center crop
            start_d = max(0, (d - pd) // 2)
            start_h = max(0, (h - ph) // 2)
            start_w = max(0, (w - pw) // 2)

        img_crop = img[:, start_d:start_d+pd, start_h:start_h+ph, start_w:start_w+pw]
        label_crop = label[start_d:start_d+pd, start_h:start_h+ph, start_w:start_w+pw]
        return img_crop, label_crop

# %%
# --- UNet3D (unchanged) ---
class UNet3D(nn.Module):
    def __init__(self, in_channels=1, out_channels=2, features=[32, 64, 128, 256]):
        super(UNet3D, self).__init__()
        self.encoder = nn.ModuleList()
        self.decoder = nn.ModuleList()
        self.pool = nn.MaxPool3d(kernel_size=2, stride=2)

        for feature in features:
            self.encoder.append(self.conv_block(in_channels, feature))
            in_channels = feature

        self.bottleneck = self.conv_block(features[-1], features[-1] * 2)

        for feature in reversed(features):
            self.decoder.append(nn.ConvTranspose3d(feature * 2, feature, kernel_size=2, stride=2))
            self.decoder.append(self.conv_block(feature * 2, feature))

        self.final_conv = nn.Conv3d(features[0], out_channels, kernel_size=1)

    def conv_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        skip_connections = []
        for down in self.encoder:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)
        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]
        for idx in range(0, len(self.decoder), 2):
            x = self.decoder[idx](x)
            skip = skip_connections[idx // 2]
            if x.shape != skip.shape:
                x = F.interpolate(x, size=skip.shape[2:], mode='trilinear', align_corners=False)
            x = self.decoder[idx + 1](torch.cat((skip, x), dim=1))
        return self.final_conv(x)

# --- Loss Functions ---
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, pred, target):
        pred = F.softmax(pred, dim=1)
        pred_flat = pred[:, 1].contiguous().view(-1)
        target_flat = (target == 1).float().view(-1)
        intersection = (pred_flat * target_flat).sum()
        dice = (2. * intersection + self.smooth) / (pred_flat.sum() + target_flat.sum() + self.smooth)
        return 1 - dice

class CombinedLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.ce = nn.CrossEntropyLoss()
        self.dice = DiceLoss()

    def forward(self, pred, target):
        return self.ce(pred, target) + self.dice(pred, target)

# --- Dice Metrics ---
def dice_coefficient(pred, target, num_classes=2):
    pred = F.softmax(pred, dim=1)
    dice_scores = []
    for cls in range(num_classes):
        pred_cls = (pred[:, cls] > 0.5).float()
        target_cls = (target == cls).float()
        intersection = (pred_cls * target_cls).sum()
        union = pred_cls.sum() + target_cls.sum()
        dice = (2. * intersection / union) if union > 0 else 1.0
        dice_scores.append(dice.item() if hasattr(dice, 'item') else float(dice))
    return dice_scores

# %%
# --- Trainer ---
def train_epoch(model, loader, optimizer, criterion, device, scaler):
    model.train()
    total_loss, all_dices = 0, []
    for data, target in tqdm(loader, desc="Training"):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        with torch.amp.autocast(device_type=device):
            output = model(data)
            loss = criterion(output, target)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
        dice = dice_coefficient(output, target)
        all_dices.append(dice)
        left_atrium_ratio = (target == 1).sum().item() / target.numel()
        logger.info(f"Left atrium voxels: {left_atrium_ratio*100:.4f}%")
    return total_loss / len(loader), np.mean(all_dices, axis=0)

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss, all_dices = 0, []
    with torch.no_grad():
        for data, target in tqdm(loader, desc="Validation"):
            data, target = data.to(device), target.to(device)
            with torch.amp.autocast(device_type=device):
                output = model(data)
                loss = criterion(output, target)
            total_loss += loss.item()
            dice = dice_coefficient(output, target)
            all_dices.append(dice)
            left_atrium_ratio = (target == 1).sum().item() / target.numel()
            logger.info(f"[VAL] Left atrium voxels: {left_atrium_ratio*100:.4f}%")
    return total_loss / len(loader), np.mean(all_dices, axis=0)

# %%
def save_checkpoint(model, optimizer, scheduler, scaler, epoch, loss, dice, save_dir, is_best=False, is_epoch=False):
    """Save checkpoint with different naming conventions"""
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'scaler_state_dict': scaler.state_dict(),
        'loss': loss,
        'dice': dice
    }
    
    if is_best:
        torch.save(checkpoint, os.path.join(save_dir, 'best_model.pth'))
        logger.info("Best model saved.")
    
    if is_epoch:
        torch.save(checkpoint, os.path.join(save_dir, f'model_epoch_{epoch}_{dice}.pth'))
        logger.info(f"Epoch {epoch} model saved.")
    
    # Always save as latest checkpoint for resuming
    torch.save(checkpoint, os.path.join(save_dir, 'latest_checkpoint.pth'))

def load_checkpoint(checkpoint_path, model, optimizer, scheduler, scaler):
    """Load checkpoint and return starting epoch"""
    if os.path.exists(checkpoint_path):
        logger.info(f"Loading checkpoint from {checkpoint_path}")
        checkpoint = torch.load(checkpoint_path, map_location='cpu',weights_only=False)
        
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        scaler.load_state_dict(checkpoint['scaler_state_dict'])
        
        start_epoch = checkpoint['epoch'] + 1
        best_dice = checkpoint.get('dice', [0, 0])[1]  # Get left atrium dice
        
        logger.info(f"Resumed from epoch {checkpoint['epoch']}, best dice: {best_dice:.4f}")
        return start_epoch, best_dice
    else:
        logger.info("No checkpoint found, starting from scratch")
        return 0, 0

# %%
# --- Main ---
def main():
    config = {
        'data_dir': r"C:\Users\dell\Desktop\HEART\Task02_Heart",
        'batch_size': 1,
        'learning_rate': 1e-4,
        'num_epochs': 10,
        'patch_size': (96, 96, 96),
        'val_split': 0.2,
        'save_dir': './checkpoints',
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'resume_from': './checkpoints/latest_checkpoint.pth',  # Auto-resume from latest
        'save_every_epoch': True  # Save model at every epoch
    }

    os.makedirs(config['save_dir'], exist_ok=True)

    with open(os.path.join(config['data_dir'], 'dataset.json'), 'r') as f:
        dataset_info = json.load(f)
    train_cases = [os.path.basename(entry['image']).replace('.nii.gz', '') for entry in dataset_info['training']]
    train_cases, val_cases = train_test_split(train_cases, test_size=config['val_split'], random_state=42)

    train_dataset = HeartDataset(config['data_dir'], train_cases, patch_size=config['patch_size'])
    val_dataset = HeartDataset(config['data_dir'], val_cases, patch_size=config['patch_size'])

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = UNet3D().to(config['device'])
    criterion = CombinedLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)
    scaler = GradScaler()

    # Load checkpoint if resuming
    start_epoch, best_dice = load_checkpoint(config['resume_from'], model, optimizer, scheduler, scaler)

    logger.info(f"Starting training from epoch {start_epoch}")
    logger.info(f"Target: Left atrium segmentation")

    for epoch in range(start_epoch, config['num_epochs']):
        logger.info(f"Epoch {epoch+1}/{config['num_epochs']}")
        train_loss, train_dice = train_epoch(model, train_loader, optimizer, criterion, config['device'], scaler)
        val_loss, val_dice = validate_epoch(model, val_loader, criterion, config['device'])
        scheduler.step(val_loss)
        
        logger.info(f"Train Loss: {train_loss:.4f}, Dice (BG/Left Atrium): {train_dice}")
        logger.info(f"Val Loss: {val_loss:.4f}, Dice (BG/Left Atrium): {val_dice}")

        # Save every epoch if requested
        if config['save_every_epoch']:
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_epoch=True)

        # Save best model based on left atrium dice (index 1)
        if val_dice[1] > best_dice:
            best_dice = val_dice[1]
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_best=True)
        
        # Always save latest checkpoint for resuming
        save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                       config['save_dir'])

    logger.info(f"Training completed. Best left atrium dice: {best_dice:.4f}")

if __name__ == '__main__':
    import multiprocessing
    multiprocessing.set_start_method('spawn', force=True)
    main()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_28992\3788910408.py:33: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# INFO:__main__:No checkpoint found, starting from scratch
# INFO:__main__:Starting training from epoch 0
# INFO:__main__:Target: Left atrium segmentation
# INFO:__main__:Epoch 1/10
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 1.7393%
# Training:   6%|▋         | 1/16 [00:01<00:15,  1.04s/it]INFO:__main__:Left atrium voxels: 2.7523%
# Training:  12%|█▎        | 2/16 [00:01<00:11,  1.22it/s]INFO:__main__:Left atrium voxels: 0.6887%
# Training:  19%|█▉        | 3/16 [00:02<00:09,  1

# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.54it/s]INFO:__main__:Left atrium voxels: 0.1941%
# Training:  50%|█████     | 8/16 [00:05<00:05,  1.50it/s]INFO:__main__:Left atrium voxels: 0.0549%
# Training:  56%|█████▋    | 9/16 [00:05<00:04,  1.50it/s]INFO:__main__:Left atrium voxels: 3.0952%
# Training:  62%|██████▎   | 10/16 [00:06<00:03,  1.55it/s]INFO:__main__:Left atrium voxels: 4.7818%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.54it/s]INFO:__main__:Left atrium voxels: 0.1363%
# Training:  75%|███████▌  | 12/16 [00:07<00:02,  1.57it/s]INFO:__main__:Left atrium voxels: 4.6519%
# Training:  81%|████████▏ | 13/16 [00:08<00:01,  1.65it/s]INFO:__main__:Left atrium voxels: 0.3950%
# Training:  88%|████████▊ | 14/16 [00:09<00:01,  1.63it/s]INFO:__main__:Left atrium voxels: 0.1426%
# Training:  94%|█████████▍| 15/16 [00:09<00:00,  1.60it/s]INFO:__main__:Left atrium voxels: 4.2701%
# Training: 100%|██████████| 16/16 [00:10<00:00,  1.54it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 2.6202%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.72it/s]INFO:__main__:[VAL] Left atrium voxels: 1.2365%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.79it/s]INFO:__main__:[VAL] Left atrium voxels: 3.9391%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.93it/s]INFO:__main__:[VAL] Left atrium voxels: 5.8180%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1.95it/s]
# INFO:__main__:Train Loss: 1.1847, Dice (BG/Left Atrium): [0.97718998 0.38209087]
# INFO:__main__:Val Loss: 1.2169, Dice (BG/Left Atrium): [0.97799698 0.01252188]
# INFO:__main__:Epoch 8 model saved.
# INFO:__main__:Epoch 10/10
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 2.5292%
# Training:   6%|▋         | 1/16 [00:00<00:11,  1.31it/s]INFO:__main__:Left atrium voxels: 3.8115%
# Training:  12%|█▎        | 2/16 [00:01<00:10,  1.40it/s]INFO:__main__:Left atrium voxels: 3.9773%
# Training:  19%|█▉        | 3/16 [00:02<00:08,  1.45it/s]INFO:__main__:Left atrium voxels: 1.7689%
# Training:  25%|██▌       | 4/16 [00:02<00:08,  1.48it/s]INFO:__main__:Left atrium voxels: 0.2315%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.53it/s]INFO:__main__:Left atrium voxels: 0.3849%
# Training:  38%|███▊      | 6/16 [00:03<00:06,  1.57it/s]INFO:__main__:Left atrium voxels: 0.4586%
# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.61it/s]INFO:__main__:Left atrium voxels: 3.3677%
# Training:  50%|█████     | 8/16 [00:05<00:04,  1.67it/s]INFO:__main__:Left atrium voxels: 3.1908%
# Training:  56%|█████▋    | 9/16 [00:05<00:04,  1.65it/s]INFO:__main__:Left atrium voxels: 1.7454%
# Training:  62%|██████▎   | 10/16 [00:06<00:03,  1.59it/s]INFO:__main__:Left atrium voxels: 1.7682%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.63it/s]INFO:__main__:Left atrium voxels: 1.7431%
# Training:  75%|███████▌  | 12/16 [00:07<00:02,  1.59it/s]INFO:__main__:Left atrium voxels: 5.8179%
# Training:  81%|████████▏ | 13/16 [00:08<00:01,  1.69it/s]INFO:__main__:Left atrium voxels: 6.2124%
# Training:  88%|████████▊ | 14/16 [00:08<00:01,  1.62it/s]INFO:__main__:Left atrium voxels: 4.1063%
# Training:  94%|█████████▍| 15/16 [00:09<00:00,  1.55it/s]INFO:__main__:Left atrium voxels: 3.7236%
# Training: 100%|██████████| 16/16 [00:10<00:00,  1.55it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 0.1324%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.60it/s]INFO:__main__:[VAL] Left atrium voxels: 1.8824%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.71it/s]INFO:__main__:[VAL] Left atrium voxels: 6.2660%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.82it/s]INFO:__main__:[VAL] Left atrium voxels: 0.7388%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1.86it/s]
# INFO:__main__:Train Loss: 1.1606, Dice (BG/Left Atrium): [0.97582769 0.46734554]
# INFO:__main__:Val Loss: 1.1322, Dice (BG/Left Atrium): [0.98826864 0.41280807]
# INFO:__main__:Epoch 9 model saved.
# INFO:__main__:Training completed. Best left atrium dice: 0.4453

# %%
# --- Main ---
def main():
    config = {
        'data_dir': r"C:\Users\dell\Desktop\HEART\Task02_Heart",
        'batch_size': 1,
        'learning_rate': 1e-4,
        'num_epochs': 25,
        'patch_size': (96, 96, 96),
        'val_split': 0.2,
        'save_dir': './checkpoints',
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'resume_from': './checkpoints/latest_checkpoint.pth',  # Auto-resume from latest
        'save_every_epoch': True  # Save model at every epoch
    }

    os.makedirs(config['save_dir'], exist_ok=True)

    with open(os.path.join(config['data_dir'], 'dataset.json'), 'r') as f:
        dataset_info = json.load(f)
    train_cases = [os.path.basename(entry['image']).replace('.nii.gz', '') for entry in dataset_info['training']]
    train_cases, val_cases = train_test_split(train_cases, test_size=config['val_split'], random_state=42)

    train_dataset = HeartDataset(config['data_dir'], train_cases, patch_size=config['patch_size'])
    val_dataset = HeartDataset(config['data_dir'], val_cases, patch_size=config['patch_size'])

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = UNet3D().to(config['device'])
    criterion = CombinedLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)
    scaler = GradScaler()

    # Load checkpoint if resuming
    start_epoch, best_dice = load_checkpoint(config['resume_from'], model, optimizer, scheduler, scaler)

    logger.info(f"Starting training from epoch {start_epoch}")
    logger.info(f"Target: Left atrium segmentation")

    for epoch in range(start_epoch, config['num_epochs']):
        logger.info(f"Epoch {epoch+1}/{config['num_epochs']}")
        train_loss, train_dice = train_epoch(model, train_loader, optimizer, criterion, config['device'], scaler)
        val_loss, val_dice = validate_epoch(model, val_loader, criterion, config['device'])
        scheduler.step(val_loss)
        
        logger.info(f"Train Loss: {train_loss:.4f}, Dice (BG/Left Atrium): {train_dice}")
        logger.info(f"Val Loss: {val_loss:.4f}, Dice (BG/Left Atrium): {val_dice}")

        # Save every epoch if requested
        if config['save_every_epoch']:
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_epoch=True)

        # Save best model based on left atrium dice (index 1)
        if val_dice[1] > best_dice:
            best_dice = val_dice[1]
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_best=True)
        
        # Always save latest checkpoint for resuming
        save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                       config['save_dir'])

    logger.info(f"Training completed. Best left atrium dice: {best_dice:.4f}")

if __name__ == '__main__':
    import multiprocessing
    multiprocessing.set_start_method('spawn', force=True)
    main()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_28992\2711278150.py:33: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# INFO:__main__:Loading checkpoint from ./checkpoints/latest_checkpoint.pth
# INFO:__main__:Resumed from epoch 9, best dice: 0.4128
# INFO:__main__:Starting training from epoch 10
# INFO:__main__:Target: Left atrium segmentation
# INFO:__main__:Epoch 11/25
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 3.6875%
# Training:   6%|▋         | 1/16 [00:00<00:10,  1.49it/s]INFO:__main__:Left atrium voxels: 6.0720%
# Training:  12%|█▎        | 2/16 [00:01<00:10,  1.39it/s]INFO:__main__:Left atrium voxels: 1.4808%
# Training:  19%|█▉        | 3/16 [00:02<00:09,  1.40it/s]INFO:__main__:Left atrium voxels: 0.1512%
# Training:  25%|██▌       | 4/16 [00:02<00:07,  1.51it/s]INFO:__main__:Left atrium voxels: 5.3312%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.49it/s]INFO:__main__:Left atrium voxels: 4.2653%
# Training:  38%|███▊      | 6/16 [00:04<00:06,  1.50it/s]INFO:__main__:Left atrium voxels: 2.8549%
# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.55it/s]INFO:__main__:Left atrium voxels: 1.1898%
# Training:  50%|█████     | 8/16 [00:05<00:05,  1.55it/s]INFO:__main__:Left atrium voxels: 3.5261%
# Training:  56%|█████▋    | 9/16 [00:05<00:04,  1.58it/s]INFO:__main__:Left atrium voxels: 3.9846%
# Training:  62%|██████▎   | 10/16 [00:06<00:03,  1.54it/s]INFO:__main__:Left atrium voxels: 2.9404%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.58it/s]INFO:__main__:Left atrium voxels: 1.6175%
# Training:  75%|███████▌  | 12/16 [00:07<00:02,  1.69it/s]INFO:__main__:Left atrium voxels: 1.3216%
# Training:  81%|████████▏ | 13/16 [00:08<00:01,  1.69it/s]INFO:__main__:Left atrium voxels: 7.6579%
# Training:  88%|████████▊ | 14/16 [00:08<00:01,  1.63it/s]INFO:__main__:Left atrium voxels: 2.0689%
# Training:  94%|█████████▍| 15/16 [00:09<00:00,  1.54it/s]INFO:__main__:Left atrium voxels: 1.6279%
# Training: 100%|██████████| 16/16 [00:10<00:00,  1.55it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 5.1944%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.65it/s]INFO:__main__:[VAL] Left atrium voxels: 2.6168%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.72it/s]INFO:__main__:[VAL] Left atrium voxels: 5.6262%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.84it/s]INFO:__main__:[VAL] Left atrium voxels: 1.3381%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1.89it/s]
# INFO:__main__:Train Loss: 1.0976, Dice (BG/Left Atrium): [0.98429879 0.58817141]
# INFO:__main__:Val Loss: 1.1885, Dice (BG/Left Atrium): [0.95437592 0.51981175]
# INFO:__main__:Epoch 10 model saved.
# INFO:__main__:Best model saved.
# INFO:__main__:Epoch 12/25
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 1.5072%
# Training:   6%|▋         | 1/16 [00:00<00:11,  1.30it/s]INFO:__main__:Left atrium voxels: 1.5953%
# Training:  12%|█▎        | 2/16 [00:01<00:10,  1.35it/s]INFO:__main__:Left atrium voxels: 0.1698%
# Training:  19%|█▉        | 3/16 [00:02<00:09,  1.40it/s]INFO:__main__:Left atrium voxels: 0.7429%
# Training:  25%|██▌       | 4/16 [00:02<00:08,  1.48it/s]INFO:__main__:Left atrium voxels: 3.7031%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.54it/s]INFO:__main__:Left atrium voxels: 3.1496%
# Training:  38%|███▊      | 6/16 [00:03<00:06,  1.59it/s]INFO:__main__:Left atrium voxels: 6.2497%
# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.56it/s]INFO:__main__:Left atrium voxels: 4.1670%
# Training:  50%|█████     | 8/16 [00:05<00:05,  1.53it/s]INFO:__main__:Left atrium voxels: 2.5071%
# Training:  56%|█████▋    | 9/16 [00:06<00:04,  1.48it/s]INFO:__main__:Left atrium voxels: 2.6062%
# Training:  62%|██████▎   | 10/16 [00:06<00:04,  1.47it/s]INFO:__main__:Left atrium voxels: 0.5934%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.51it/s]INFO:__main__:Left atrium voxels: 4.2519%
# Training:  75%|███████▌  | 12/16 [00:08<00:02,  1.50it/s]INFO:__main__:Left atrium voxels: 5.6363%
# Training:  81%|████████▏ | 13/16 [00:08<00:02,  1.49it/s]INFO:__main__:Left atrium voxels: 1.6940%
# Training:  88%|████████▊ | 14/16 [00:09<00:01,  1
model saved.
# INFO:__main__:Best model saved.
# INFO:__main__:Epoch 24/25
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 0.1547%
# Training:   6%|▋         | 1/16 [00:00<00:13,  1.12it/s]INFO:__main__:Left atrium voxels: 0.1585%
# Training:  12%|█▎        | 2/16 [00:01<00:10,  1.38it/s]INFO:__main__:Left atrium voxels: 4.2519%
# Training:  19%|█▉        | 3/16 [00:02<00:09,  1.43it/s]INFO:__main__:Left atrium voxels: 2.0446%
# Training:  25%|██▌       | 4/16 [00:02<00:08,  1.46it/s]INFO:__main__:Left atrium voxels: 0.1935%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.55it/s]INFO:__main__:Left atrium voxels: 1.5795%
# Training:  38%|███▊      | 6/16 [00:04<00:06,  1.55it/s]INFO:__main__:Left atrium voxels: 5.1493%
# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.53it/s]INFO:__main__:Left atrium voxels: 3.3075%
# Training:  50%|█████     | 8/16 [00:05<00:05,  1.52it/s]INFO:__main__:Left atrium voxels: 4.8833%
# Training:  56%|█████▋    | 9/16 [00:05<00:04,  1.56it/s]INFO:__main__:Left atrium voxels: 2.9339%
# Training:  62%|██████▎   | 10/16 [00:06<00:03,  1.68it/s]INFO:__main__:Left atrium voxels: 2.9319%
# Training:  69%|██████▉   | 11/16 [00:07<00:02,  1.69it/s]INFO:__main__:Left atrium voxels: 5.1819%
# Training:  75%|███████▌  | 12/16 [00:07<00:02,  1.62it/s]INFO:__main__:Left atrium voxels: 0.0547%
# Training:  81%|████████▏ | 13/16 [00:08<00:01,  1.62it/s]INFO:__main__:Left atrium voxels: 2.0952%
# Training:  88%|████████▊ | 14/16 [00:09<00:01,  1.59it/s]INFO:__main__:Left atrium voxels: 2.8896%
# Training:  94%|█████████▍| 15/16 [00:09<00:00,  1.62it/s]INFO:__main__:Left atrium voxels: 3.6214%
# Training: 100%|██████████| 16/16 [00:10<00:00,  1.57it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 1.8158%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.71it/s]INFO:__main__:[VAL] Left atrium voxels: 1.0647%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.78it/s]INFO:__main__:[VAL] Left atrium voxels: 0.7017%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.89it/s]INFO:__main__:[VAL] Left atrium voxels: 1.0576%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1.93it/s]
# INFO:__main__:Train Loss: 0.9053, Dice (BG/Left Atrium): [0.99446988 0.71042462]
# INFO:__main__:Val Loss: 1.0650, Dice (BG/Left Atrium): [0.9914156  0.39777885]
# INFO:__main__:Epoch 23 model saved.
# INFO:__main__:Epoch 25/25
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 1.6803%
# Training:   6%|▋         | 1/16 [00:00<00:11,  1.32it/s]INFO:__main__:Left atrium voxels: 4.3775%
# Training:  12%|█▎        | 2/16 [00:01<00:10,  1.39it/s]INFO:__main__:Left atrium voxels: 0.3242%
# Training:  19%|█▉        | 3/16 [00:02<00:08,  1.50it/s]INFO:__main__:Left atrium voxels: 2.6177%
# Training:  25%|██▌       | 4/16 [00:02<00:08,  1.46it/s]INFO:__main__:Left atrium voxels: 5.3949%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.45it/s]INFO:__main__:Left atrium voxels: 4.4545%
# Training:  38%|███▊      | 6/16 [00:04<00:06,  1.52it/s]INFO:__main__:Left atrium voxels: 3.1737%
# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.59it/s]INFO:__main__:Left atrium voxels: 0.0601%
# Training:  50%|█████     | 8/16 [00:05<00:05,  1.58it/s]INFO:__main__:Left atrium voxels: 0.2135%
# Training:  56%|█████▋    | 9/16 [00:05<00:04,  1.69it/s]INFO:__main__:Left atrium voxels: 4.2185%
# Training:  62%|██████▎   | 10/16 [00:06<00:03,  1.70it/s]INFO:__main__:Left atrium voxels: 3.8029%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.62it/s]INFO:__main__:Left atrium voxels: 0.6802%
# Training:  75%|███████▌  | 12/16 [00:07<00:02,  1.57it/s]INFO:__main__:Left atrium voxels: 1.9868%
# Training:  81%|████████▏ | 13/16 [00:08<00:01,  1.59it/s]INFO:__main__:Left atrium voxels: 3.0106%
# Training:  88%|████████▊ | 14/16 [00:08<00:01,  1.60it/s]INFO:__main__:Left atrium voxels: 1.1860%
# Training:  94%|█████████▍| 15/16 [00:09<00:00,  1.55it/s]INFO:__main__:Left atrium voxels: 4.2701%
# Training: 100%|██████████| 16/16 [00:10<00:00,  1.55it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 0.3772%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.64it/s]INFO:__main__:[VAL] Left atrium voxels: 0.1146%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.72it/s]INFO:__main__:[VAL] Left atrium voxels: 0.4144%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.85it/s]INFO:__main__:[VAL] Left atrium voxels: 1.2009%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1.89it/s]
# INFO:__main__:Train Loss: 0.8990, Dice (BG/Left Atrium): [0.99406027 0.70103769]
# INFO:__main__:Val Loss: 1.1119, Dice (BG/Left Atrium): [0.99737832 0.0700386 ]
# INFO:__main__:Epoch 24 model saved.
# INFO:__main__:Training completed. Best left atrium dice: 0.8538

# %%
# --- Main ---
def main():
    config = {
        'data_dir': r"C:\Users\dell\Desktop\HEART\Task02_Heart",
        'batch_size': 1,
        'learning_rate': 1e-4,
        'num_epochs': 35,
        'patch_size': (96, 96, 96),
        'val_split': 0.2,
        'save_dir': './checkpoints',
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'resume_from': './checkpoints/latest_checkpoint.pth',  # Auto-resume from latest
        'save_every_epoch': True  # Save model at every epoch
    }

    os.makedirs(config['save_dir'], exist_ok=True)

    with open(os.path.join(config['data_dir'], 'dataset.json'), 'r') as f:
        dataset_info = json.load(f)
    train_cases = [os.path.basename(entry['image']).replace('.nii.gz', '') for entry in dataset_info['training']]
    train_cases, val_cases = train_test_split(train_cases, test_size=config['val_split'], random_state=42)

    train_dataset = HeartDataset(config['data_dir'], train_cases, patch_size=config['patch_size'])
    val_dataset = HeartDataset(config['data_dir'], val_cases, patch_size=config['patch_size'])

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = UNet3D().to(config['device'])
    criterion = CombinedLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)
    scaler = GradScaler()

    # Load checkpoint if resuming
    start_epoch, best_dice = load_checkpoint(config['resume_from'], model, optimizer, scheduler, scaler)

    logger.info(f"Starting training from epoch {start_epoch}")
    logger.info(f"Target: Left atrium segmentation")

    for epoch in range(start_epoch, config['num_epochs']):
        logger.info(f"Epoch {epoch+1}/{config['num_epochs']}")
        train_loss, train_dice = train_epoch(model, train_loader, optimizer, criterion, config['device'], scaler)
        val_loss, val_dice = validate_epoch(model, val_loader, criterion, config['device'])
        scheduler.step(val_loss)
        
        logger.info(f"Train Loss: {train_loss:.4f}, Dice (BG/Left Atrium): {train_dice}")
        logger.info(f"Val Loss: {val_loss:.4f}, Dice (BG/Left Atrium): {val_dice}")

        # Save every epoch if requested
        if config['save_every_epoch']:
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_epoch=True)

        # Save best model based on left atrium dice (index 1)
        if val_dice[1] > best_dice:
            best_dice = val_dice[1]
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_best=True)
        
        # Always save latest checkpoint for resuming
        save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                       config['save_dir'])

    logger.info(f"Training completed. Best left atrium dice: {best_dice:.4f}")

if __name__ == '__main__':
    import multiprocessing
    multiprocessing.set_start_method('spawn', force=True)
    main()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12132\307088344.py:33: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# INFO:__main__:Loading checkpoint from ./checkpoints/latest_checkpoint.pth
# INFO:__main__:Resumed from epoch 24, best dice: 0.0700
# INFO:__main__:Starting training from epoch 25
# INFO:__main__:Target: Left atrium segmentation
# INFO:__main__:Epoch 26/35
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 0.4136%
# Training:   6%|▋         | 1/16 [00:01<00:16,  1.09s/it]INFO:__main__:Left atrium voxels: 0.0982%
# Training:  12%|█▎        | 2/16 [00:01<00:11,  1.22it/s]INFO:__main__:Left atrium voxels: 0.8104%
# Training:  19%|█▉        | 3/16 [00:02<00:09,  1.32it/s]INFO:__main__:Left atrium voxels: 2.6825%
# Training:  25%|██▌       | 4/16 [00:03<00:08,  1.35it/s]INFO:__main__:Left atrium voxels: 5.1713%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.45it/s]INFO:__main__:Left atrium voxels: 1.6198%
# Training:  38%|███▊      | 6/16 [00:04<00:06,  1.49it/s]INFO:__main__:Left atrium voxels: 4.9302%
# Training:  44%|████▍     | 7/16 [00:05<00:06,  1.46it/s]INFO:__main__:Left atrium voxels: 4.9832%
# Training:  50%|█████     | 8/16 [00:05<00:05,  1.56it/s]INFO:__main__:Left atrium voxels: 1.5743%
# Training:  56%|█████▋    | 9/16 [00:06<00:04,  1.49it/s]INFO:__main__:Left atrium voxels: 1.6411%
# Training:  62%|██████▎   | 10/16 [00:07<00:04,  1.47it/s]INFO:__main__:Left atrium voxels: 4.3875%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.45it/s]INFO:__main__:Left atrium voxels: 1.3558%
# Training:  75%|███████▌  | 12/16 [00:08<00:02,  1.44it/s]INFO:__main__:Left atrium voxels: 0.1980%
# Training:  81%|████████▏ | 13/16 [00:09<00:02,  1.43it/s]INFO:__main__:Left atrium voxels: 2.8887%
# Training:  88%|████████▊ | 14/16 [00:09<00:01,  1.47it/s]INFO:__main__:Left atrium voxels: 1.5072%
# Training:  94%|█████████▍| 15/16 [00:10<00:00,  1.48it/s]INFO:__main__:Left atrium voxels: 0.2375%
# Training: 100%|██████████| 16/16 [00:11<00:00,  1.44it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 1.0087%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.58it/s]INFO:__main__:[VAL] Left atrium voxels: 4.7147%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.64it/s]INFO:__main__:[VAL] Left atrium voxels: 0.1564%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.72it/s]INFO:__main__:[VAL] Left atrium voxels: 0.0541%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1
model saved.
# INFO:__main__:Best model saved.
# INFO:__main__:Epoch 35/35
# Training:   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 0.9138%
# Training:   6%|▋         | 1/16 [00:00<00:12,  1.17it/s]INFO:__main__:Left atrium voxels: 0.4762%
# Training:  12%|█▎        | 2/16 [00:01<00:10,  1.31it/s]INFO:__main__:Left atrium voxels: 0.1413%
# Training:  19%|█▉        | 3/16 [00:02<00:09,  1.40it/s]INFO:__main__:Left atrium voxels: 0.2461%
# Training:  25%|██▌       | 4/16 [00:02<00:08,  1.37it/s]INFO:__main__:Left atrium voxels: 1.4581%
# Training:  31%|███▏      | 5/16 [00:03<00:07,  1.38it/s]INFO:__main__:Left atrium voxels: 0.0549%
# Training:  38%|███▊      | 6/16 [00:04<00:07,  1.41it/s]INFO:__main__:Left atrium voxels: 0.6932%
# Training:  44%|████▍     | 7/16 [00:04<00:05,  1.55it/s]INFO:__main__:Left atrium voxels: 2.8978%
# Training:  50%|█████     | 8/16 [00:05<00:04,  1.63it/s]INFO:__main__:Left atrium voxels: 3.7922%
# Training:  56%|█████▋    | 9/16 [00:06<00:04,  1.62it/s]INFO:__main__:Left atrium voxels: 3.6855%
# Training:  62%|██████▎   | 10/16 [00:06<00:03,  1.63it/s]INFO:__main__:Left atrium voxels: 4.8178%
# Training:  69%|██████▉   | 11/16 [00:07<00:03,  1.63it/s]INFO:__main__:Left atrium voxels: 2.1603%
# Training:  75%|███████▌  | 12/16 [00:07<00:02,  1.67it/s]INFO:__main__:Left atrium voxels: 4.4085%
# Training:  81%|████████▏ | 13/16 [00:08<00:01,  1.60it/s]INFO:__main__:Left atrium voxels: 3.0000%
# Training:  88%|████████▊ | 14/16 [00:09<00:01,  1.60it/s]INFO:__main__:Left atrium voxels: 0.2332%
# Training:  94%|█████████▍| 15/16 [00:09<00:00,  1.57it/s]INFO:__main__:Left atrium voxels: 5.0842%
# Training: 100%|██████████| 16/16 [00:10<00:00,  1.54it/s]
# Validation:   0%|          | 0/4 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 1.6747%
# Validation:  25%|██▌       | 1/4 [00:00<00:01,  1.68it/s]INFO:__main__:[VAL] Left atrium voxels: 4.9713%
# Validation:  50%|█████     | 2/4 [00:01<00:01,  1.72it/s]INFO:__main__:[VAL] Left atrium voxels: 2.9266%
# Validation:  75%|███████▌  | 3/4 [00:01<00:00,  1.81it/s]INFO:__main__:[VAL] Left atrium voxels: 1.3593%
# Validation: 100%|██████████| 4/4 [00:02<00:00,  1.87it/s]
# INFO:__main__:Train Loss: 0.8285, Dice (BG/Left Atrium): [0.99645147 0.72206552]
# INFO:__main__:Val Loss: 0.7827, Dice (BG/Left Atrium): [0.99277981 0.77876422]
# INFO:__main__:Epoch 34 model saved.
# INFO:__main__:Training completed. Best left atrium dice: 0.8101

# %%
# --- Main ---
def main():
    config = {
        'data_dir': r"C:\Users\dell\Desktop\HEART\Task02_Heart",
        'batch_size': 1,
        'learning_rate': 1e-4,
        'num_epochs': 50,
        'patch_size': (96, 96, 96),
        'val_split': 0.25,
        'save_dir': './checkpoints',
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'resume_from': './checkpoints/latest_checkpoint.pth',  # Auto-resume from latest
        'save_every_epoch': True  # Save model at every epoch
    }

    os.makedirs(config['save_dir'], exist_ok=True)

    with open(os.path.join(config['data_dir'], 'dataset.json'), 'r') as f:
        dataset_info = json.load(f)
    train_cases = [os.path.basename(entry['image']).replace('.nii.gz', '') for entry in dataset_info['training']]
    train_cases, val_cases = train_test_split(train_cases, test_size=config['val_split'], random_state=42)

    train_dataset = HeartDataset(config['data_dir'], train_cases, patch_size=config['patch_size'])
    val_dataset = HeartDataset(config['data_dir'], val_cases, patch_size=config['patch_size'])

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = UNet3D().to(config['device'])
    criterion = CombinedLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)
    scaler = GradScaler()

    # Load checkpoint if resuming
    start_epoch, best_dice = load_checkpoint(config['resume_from'], model, optimizer, scheduler, scaler)

    logger.info(f"Starting training from epoch {start_epoch}")
    logger.info(f"Target: Left atrium segmentation")

    for epoch in range(start_epoch, config['num_epochs']):
        logger.info(f"Epoch {epoch+1}/{config['num_epochs']}")
        train_loss, train_dice = train_epoch(model, train_loader, optimizer, criterion, config['device'], scaler)
        val_loss, val_dice = validate_epoch(model, val_loader, criterion, config['device'])
        scheduler.step(val_loss)
        
        logger.info(f"Train Loss: {train_loss:.4f}, Dice (BG/Left Atrium): {train_dice}")
        logger.info(f"Val Loss: {val_loss:.4f}, Dice (BG/Left Atrium): {val_dice}")

        # Save every epoch if requested
        if config['save_every_epoch']:
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_epoch=True)

        # Save best model based on left atrium dice (index 1)
        if val_dice[1] > best_dice:
            best_dice = val_dice[1]
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_best=True)
        
        # Always save latest checkpoint for resuming
        save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                       config['save_dir'])

    logger.info(f"Training completed. Best left atrium dice: {best_dice:.4f}")

if __name__ == '__main__':
    import multiprocessing
    multiprocessing.set_start_method('spawn', force=True)
    main()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12132\113038907.py:33: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# INFO:__main__:Loading checkpoint from ./checkpoints/latest_checkpoint.pth
# INFO:__main__:Resumed from epoch 34, best dice: 0.7788
# INFO:__main__:Starting training from epoch 35
# INFO:__main__:Target: Left atrium segmentation
# INFO:__main__:Epoch 36/50
# Training:   0%|          | 0/15 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 6.5795%
# Training:   7%|▋         | 1/15 [00:01<00:15,  1.13s/it]INFO:__main__:Left atrium voxels: 0.5337%
# Training:  13%|█▎        | 2/15 [00:01<00:11,  1.15it/s]INFO:__main__:Left atrium voxels: 2.1766%
# Training:  20%|██        | 3/15 [00:02<00:09,  1.27it/s]INFO:__main__:Left atrium voxels: 4.2661%
# Training:  27%|██▋       | 4/15 [00:03<00:08,  1.34it/s]INFO:__main__:Left atrium voxels: 0.9393%
# Training:  33%|███▎      | 5/15 [00:03<00:06,  1.45it/s]INFO:__main__:Left atrium voxels: 1.8065%
# Training:  40%|████      | 6/15 [00:04<00:06,  1.47it/s]INFO:__main__:Left atrium voxels: 0.4492%
# Training:  47%|████▋     | 7/15 [00:04<00:05,  1.59it/s]INFO:__main__:Left atrium voxels: 3.6855%
# Training:  53%|█████▎    | 8/15 [00:05<00:04,  1.62it/s]INFO:__main__:Left atrium voxels: 0.3855%
# Training:  60%|██████    | 9/15 [00:06<00:03,  1.61it/s]INFO:__main__:Left atrium voxels: 3.8027%
# Training:  67%|██████▋   | 10/15 [00:06<00:03,  1.61it/s]INFO:__main__:Left atrium voxels: 0.9356%
# Training:  73%|███████▎  | 11/15 [00:07<00:02,  1.58it/s]INFO:__main__:Left atrium voxels: 1.0257%
# Training:  80%|████████  | 12/15 [00:08<00:01,  1.65it/s]INFO:__main__:Left atrium voxels: 1.4361%
# Training:  87%|████████▋ | 13/15 [00:08<00:01,  1.69it/s]INFO:__main__:Left atrium voxels: 0.3363%
# Training:  93%|█████████▎| 14/15 [00:09<00:00,  1.63it/s]INFO:__main__:Left atrium voxels: 3.6214%
# Training: 100%|██████████| 15/15 [00:09<00:00,  1.53it/s]
# Validation:   0%|          | 0/5 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 1.1218%
# Validation:  20%|██        | 1/5 [00:00<00:02,  1.68it/s]INFO:__main__:[VAL] Left atrium voxels: 5.2290%
# Validation:  40%|████      | 2/5 [00:01<00:01,  1.78it/s]INFO:__main__:[VAL] Left atrium voxels: 3.8041%
# Validation:  60%|██████    | 3/5 [00:01<00:01,  1.91it/s]INFO:__main__:[VAL] Left atrium voxels: 1.9823%
# Validation:  80%|████████  | 4/5 [00:02<00:00,  2.00it/s]INFO:__main__:[VAL] Left atrium voxels: 1.1799%
# Validation: 100%|██████████| 5/5 [00:02<00:00,  1.86it/s]
# INFO:__main__:Train Loss: 0.8209, Dice (BG/Left Atrium): [0.99591684 0.76159926]
# INFO:__main__:Val Loss: 0.8300, Dice (BG/Left Atrium): [0.99165027 0.6893661 ]
# INFO:__main__:Epoch 35 model saved.
# INFO:__main__:Epoch 37/50
# Training:   0%|          | 0/15 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 0
[00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 1.8309%
# Training:   7%|▋         | 1/15 [00:00<00:10,  1.31it/s]INFO:__main__:Left atrium voxels: 4.7947%
# Training:  13%|█▎        | 2/15 [00:01<00:08,  1.45it/s]INFO:__main__:Left atrium voxels: 3.5590%
# Training:  20%|██        | 3/15 [00:02<00:07,  1.53it/s]INFO:__main__:Left atrium voxels: 3.3651%
# Training:  27%|██▋       | 4/15 [00:02<00:07,  1.52it/s]INFO:__main__:Left atrium voxels: 3.5771%
# Training:  33%|███▎      | 5/15 [00:03<00:06,  1.61it/s]INFO:__main__:Left atrium voxels: 6.4339%
# Training:  40%|████      | 6/15 [00:03<00:05,  1.57it/s]INFO:__main__:Left atrium voxels: 0.3818%
# Training:  47%|████▋     | 7/15 [00:04<00:05,  1.56it/s]INFO:__main__:Left atrium voxels: 0.1738%
# Training:  53%|█████▎    | 8/15 [00:05<00:04,  1.59it/s]INFO:__main__:Left atrium voxels: 2.5757%
# Training:  60%|██████    | 9/15 [00:05<00:03,  1.56it/s]INFO:__main__:Left atrium voxels: 1.8997%
# Training:  67%|██████▋   | 10/15 [00:06<00:02,  1.68it/s]INFO:__main__:Left atrium voxels: 1.2915%
# Training:  73%|███████▎  | 11/15 [00:06<00:02,  1.72it/s]INFO:__main__:Left atrium voxels: 1.7981%
# Training:  80%|████████  | 12/15 [00:07<00:01,  1.70it/s]INFO:__main__:Left atrium voxels: 6.5404%
# Training:  87%|████████▋ | 13/15 [00:08<00:01,  1.63it/s]INFO:__main__:Left atrium voxels: 4.5588%
# Training:  93%|█████████▎| 14/15 [00:08<00:00,  1.59it/s]INFO:__main__:Left atrium voxels: 3.2727%
# Training: 100%|██████████| 15/15 [00:09<00:00,  1.60it/s]
# Validation:   0%|          | 0/5 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 2.0229%
# Validation:  20%|██        | 1/5 [00:00<00:02,  1.71it/s]INFO:__main__:[VAL] Left atrium voxels: 3.2033%
# Validation:  40%|████      | 2/5 [00:01<00:01,  1.77it/s]INFO:__main__:[VAL] Left atrium voxels: 0.4869%
# Validation:  60%|██████    | 3/5 [00:01<00:01,  1.89it/s]INFO:__main__:[VAL] Left atrium voxels: 3.3473%
# Validation:  80%|████████  | 4/5 [00:02<00:00,  2.01it/s]INFO:__main__:[VAL] Left atrium voxels: 0.3393%
# Validation: 100%|██████████| 5/5 [00:02<00:00,  1.85it/s]
# INFO:__main__:Train Loss: 0.5659, Dice (BG/Left Atrium): [0.99577951 0.82200479]
# INFO:__main__:Val Loss: 0.7972, Dice (BG/Left Atrium): [0.99537311 0.48879656]
# INFO:__main__:Epoch 49 model saved.
# INFO:__main__:Training completed. Best left atrium dice: 0.8587

# %%
# --- Main ---
def main():
    config = {
        'data_dir': r"C:\Users\dell\Desktop\HEART\Task02_Heart",
        'batch_size': 1,
        'learning_rate': 1e-4,
        'num_epochs': 65,
        'patch_size': (96, 96, 96),
        'val_split': 0.3,
        'save_dir': './checkpoints',
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'resume_from': './checkpoints/best_model.pth',  # Auto-resume from latest
        'save_every_epoch': True  # Save model at every epoch
    }

    os.makedirs(config['save_dir'], exist_ok=True)

    with open(os.path.join(config['data_dir'], 'dataset.json'), 'r') as f:
        dataset_info = json.load(f)
    train_cases = [os.path.basename(entry['image']).replace('.nii.gz', '') for entry in dataset_info['training']]
    train_cases, val_cases = train_test_split(train_cases, test_size=config['val_split'], random_state=42)

    train_dataset = HeartDataset(config['data_dir'], train_cases, patch_size=config['patch_size'])
    val_dataset = HeartDataset(config['data_dir'], val_cases, patch_size=config['patch_size'])

    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = UNet3D().to(config['device'])
    criterion = CombinedLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)
    scaler = GradScaler()

    # Load checkpoint if resuming
    start_epoch, best_dice = load_checkpoint(config['resume_from'], model, optimizer, scheduler, scaler)

    logger.info(f"Starting training from epoch {start_epoch}")
    logger.info(f"Target: Left atrium segmentation")

    for epoch in range(start_epoch, config['num_epochs']):
        logger.info(f"Epoch {epoch+1}/{config['num_epochs']}")
        train_loss, train_dice = train_epoch(model, train_loader, optimizer, criterion, config['device'], scaler)
        val_loss, val_dice = validate_epoch(model, val_loader, criterion, config['device'])
        scheduler.step(val_loss)
        
        logger.info(f"Train Loss: {train_loss:.4f}, Dice (BG/Left Atrium): {train_dice}")
        logger.info(f"Val Loss: {val_loss:.4f}, Dice (BG/Left Atrium): {val_dice}")

        # Save every epoch if requested
        if config['save_every_epoch']:
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_epoch=True)

        # Save best model based on left atrium dice (index 1)
        if val_dice[1] > best_dice:
            best_dice = val_dice[1]
            save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                          config['save_dir'], is_best=True)
        
        # Always save latest checkpoint for resuming
        save_checkpoint(model, optimizer, scheduler, scaler, epoch, val_loss, val_dice, 
                       config['save_dir'])

    logger.info(f"Training completed. Best left atrium dice: {best_dice:.4f}")

if __name__ == '__main__':
    import multiprocessing
    multiprocessing.set_start_method('spawn', force=True)
    main()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12132\3338711828.py:33: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# INFO:__main__:Loading checkpoint from ./checkpoints/best_model.pth
# INFO:__main__:Resumed from epoch 42, best dice: 0.8587
# INFO:__main__:Starting training from epoch 43
# INFO:__main__:Target: Left atrium segmentation
# INFO:__main__:Epoch 44/65
# Training:   0%|          | 0/14 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 0.1324%
# Training:   7%|▋         | 1/14 [00:01<00:13,  1.07s/it]INFO:__main__:Left atrium voxels: 0.0904%
# Training:  14%|█▍        | 2/14 [00:01<00:09,  1.24it/s]INFO:__main__:Left atrium voxels: 4.2683%
# Training:  21%|██▏       | 3/14 [00:02<00:08,  1.31it/s]INFO:__main__:Left atrium voxels: 0.5290%
# Training:  29%|██▊       | 4/14 [00:03<00:07,  1.40it/s]INFO:__main__:Left atrium voxels: 4.3338%
# Training:  36%|███▌      | 5/14 [00:03<00:06,  1.48it/s]INFO:__main__:Left atrium voxels: 5.3249%
# Training:  43%|████▎     | 6/14 [00:04<00:05,  1.58it/s]INFO:__main__:Left atrium voxels: 2.8746%
# Training:  50%|█████     | 7/14 [00:04<00:04,  1.61it/s]INFO:__main__:Left atrium voxels: 0.1138%
# Training:  57%|█████▋    | 8/14 [00:05<00:03,  1.63it/s]INFO:__main__:Left atrium voxels: 0.6742%
# Training:  64%|██████▍   | 9/14 [00:06<00:03,  1.59it/s]INFO:__main__:Left atrium voxels: 0.2343%
# Training:  71%|███████▏  | 10/14 [00:06<00:02,  1.56it/s]INFO:__main__:Left atrium voxels: 7.6384%
# Training:  79%|███████▊  | 11/14 [00:07<00:01,  1.53it/s]INFO:__main__:Left atrium voxels: 0.7532%
# Training:  86%|████████▌ | 12/14 [00:07<00:01,  1.60it/s]INFO:__main__:Left atrium voxels: 3.0836%
# Training:  93%|█████████▎| 13/14 [00:08<00:00,  1.55it/s]INFO:__main__:Left atrium voxels: 3.5623%
# Training: 100%|██████████| 14/14 [00:09<00:00,  1.53it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 1.4130%
# Validation:  17%|█▋        | 1/6 [00:00<00:02,  1.73it/s]INFO:__main__:[VAL] Left atrium voxels: 0.7116%
# Validation:  33%|███▎      | 2/6 [00:01<00:02,  1.81it/s]INFO:__main__:[VAL] Left atrium voxels: 4.0099%
# Validation:  50%|█████     | 3/6 [00:01<00:01,  1.91it/s]INFO:__main__:[VAL] Left atrium voxels: 6.1351%
# Validation:  67%|██████▋   | 4/6 [00:02<00:00,  2.04it/s]INFO:__main__:[VAL] Left atrium voxels: 4.8964%
# Validation:  83%|████████▎ | 5/6 [00:02<00:00,  1.84it/s]INFO:__main__:[VAL] Left atrium voxels: 2.3175%
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.84it/s]
# INFO:__main__:Train Loss: 0.7368, Dice (BG/Left Atrium): [0.99667945 0.74910216]
# INFO:__main__:Val Loss: 0.6326, Dice (BG/Left Atrium): [0.99656143 0.85657089]
# INFO:__main__:Epoch 43 model saved.
# INFO:__main__:Epoch 45/65
# Training:   0%|          | 0/14 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 2.8850%
# Training:   7%|▋         | 1/14 [00:00<00:08,  1.52it/s]INFO:__main__:Left atrium voxels: 3.9149%
# Training:  14%|█▍        | 2/14 [00:01<00:06,  1.77it/s]INFO:__main__:Left atrium voxels: 0.7262%
# Training:  21%|██▏       | 3/14 [00:01<00:06,  1.71it/s]INFO:__main__:Left atrium voxels: 0.0604%
# Training:  29%|██▊       | 4/14 [00:02<00:06,  1

# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.83it/s]
# INFO:__main__:Train Loss: 0.5333, Dice (BG/Left Atrium): [0.99704395 0.81035545]
# INFO:__main__:Val Loss: 0.6346, Dice (BG/Left Atrium): [0.9951268  0.72162992]
# INFO:__main__:Epoch 63 model saved.
# INFO:__main__:Epoch 65/65
# Training:   0%|          | 0/14 [00:00<?, ?it/s]INFO:__main__:Left atrium voxels: 0.4178%
# Training:   7%|▋         | 1/14 [00:00<00:10,  1.19it/s]INFO:__main__:Left atrium voxels: 4.4957%
# Training:  14%|█▍        | 2/14 [00:01<00:09,  1.29it/s]INFO:__main__:Left atrium voxels: 4.8833%
# Training:  21%|██▏       | 3/14 [00:02<00:07,  1.42it/s]INFO:__main__:Left atrium voxels: 6.3602%
# Training:  29%|██▊       | 4/14 [00:02<00:06,  1.46it/s]INFO:__main__:Left atrium voxels: 3.0608%
# Training:  36%|███▌      | 5/14 [00:03<00:05,  1.52it/s]INFO:__main__:Left atrium voxels: 5.8581%
# Training:  43%|████▎     | 6/14 [00:04<00:05,  1.49it/s]INFO:__main__:Left atrium voxels: 1.4818%
# Training:  50%|█████     | 7/14 [00:04<00:04,  1.58it/s]INFO:__main__:Left atrium voxels: 4.0848%
# Training:  57%|█████▋    | 8/14 [00:05<00:03,  1.56it/s]INFO:__main__:Left atrium voxels: 4.7515%
# Training:  64%|██████▍   | 9/14 [00:05<00:03,  1.62it/s]INFO:__main__:Left atrium voxels: 3.6855%
# Training:  71%|███████▏  | 10/14 [00:06<00:02,  1.63it/s]INFO:__main__:Left atrium voxels: 1.7526%
# Training:  79%|███████▊  | 11/14 [00:07<00:01,  1.58it/s]INFO:__main__:Left atrium voxels: 5.0842%
# Training:  86%|████████▌ | 12/14 [00:07<00:01,  1.59it/s]INFO:__main__:Left atrium voxels: 5.8179%
# Training:  93%|█████████▎| 13/14 [00:08<00:00,  1.69it/s]INFO:__main__:Left atrium voxels: 3.5994%
# Training: 100%|██████████| 14/14 [00:08<00:00,  1.57it/s]
# Validation:   0%|          | 0/6 [00:00<?, ?it/s]INFO:__main__:[VAL] Left atrium voxels: 6.1251%
# Validation:  17%|█▋        | 1/6 [00:00<00:02,  1.71it/s]INFO:__main__:[VAL] Left atrium voxels: 0.3990%
# Validation:  33%|███▎      | 2/6 [00:01<00:02,  1.79it/s]INFO:__main__:[VAL] Left atrium voxels: 1.0625%
# Validation:  50%|█████     | 3/6 [00:01<00:01,  1.91it/s]INFO:__main__:[VAL] Left atrium voxels: 0.9729%
# Validation:  67%|██████▋   | 4/6 [00:02<00:00,  2.04it/s]INFO:__main__:[VAL] Left atrium voxels: 1.5249%
# Validation:  83%|████████▎ | 5/6 [00:02<00:00,  1.85it/s]INFO:__main__:[VAL] Left atrium voxels: 0.4962%
# Validation: 100%|██████████| 6/6 [00:03<00:00,  1.84it/s]
# INFO:__main__:Train Loss: 0.3739, Dice (BG/Left Atrium): [0.99589865 0.89443502]
# INFO:__main__:Val Loss: 0.6841, Dice (BG/Left Atrium): [0.99708026 0.60688349]
# INFO:__main__:Epoch 64 model saved.
# INFO:__main__:Training completed. Best left atrium dice: 0.8776
